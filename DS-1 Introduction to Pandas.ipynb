# %%
import pandas as pd

# %%
rain = pd.read_csv("C:\\Users\\12142\\Desktop\\rain.csv")

# %%
rain
# Out:
#       Cardiff  Stornoway  Oxford  Armagh
# 1853      NaN        NaN    57.7    53.0
# 1854      NaN        NaN    37.5    69.8
# 1855      NaN        NaN    53.4    50.2
# 1856      NaN        NaN    57.2    55.0
# 1857      NaN        NaN    61.3    64.6
# ...       ...        ...     ...     ...
# 2016     99.3      100.0    54.8    61.4
# 2017     85.0      103.1    48.1    60.7
# 2018     99.3       96.8    48.9    67.6
# 2019    119.0      105.6    60.5    72.7
# 2020    117.6      121.1    64.2    71.3
#
# [168 rows x 4 columns]

# %%
# Average rain fall or the mean rainfall
rain.mean()
# Out:
# Cardiff       97.400000
# Stornoway    100.316892
# Oxford        54.787500
# Armagh        68.803571
# dtype: float64

# %%
# How many years was the average rainfall above 100 mm for each city:
rain[rain > 100].count()
# Out:
# Cardiff      13
# Stornoway    74
# Oxford        0
# Armagh        1
# dtype: int64

# %%
# Display onle one Column/City
Oxford = rain['Oxford']

# %%
Oxford
# Out:
# 1853    57.7
# 1854    37.5
# 1855    53.4
# 1856    57.2
# 1857    61.3
#         ...
# 2016    54.8
# 2017    48.1
# 2018    48.9
# 2019    60.5
# 2020    64.2
# Name: Oxford, Length: 168, dtype: float64

# %% [markdown]
# **Ploting Data**

# %%
rain.plot(xlabel = "Date", ylabel = "Average Monthly Rainfall (mm)")
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Average Monthly Rainfall (mm)'>

# %%
cp = pd.read_csv("city_pop.csv")

# %%
cp
# Out:
#                           This is an example CSV file
# 0   The text at the top here is not part of the da...
# 1   to describe the file. You'll see this quite of...
# 2                     A -1 signifies a missing value.
# 3                              year;London;Paris;Rome
# 4                              2001;7.322;2.148;2.547
# 5                                   2006;7.652;;2.627
# 6                                      2008;-1;2.211;
# 7                                 2009;-1;2.234;2.734
# 8                                        2011;8.174;;
# 9                                 2012;-1;2.244;2.627
# 10                                       2015;8.615;;

# %%
# Removing the first five rows
pd.read_csv("city_pop.csv", skiprows=5)
# Out:
#    year;London;Paris;Rome
# 0  2001;7.322;2.148;2.547
# 1       2006;7.652;;2.627
# 2          2008;-1;2.211;
# 3     2009;-1;2.234;2.734
# 4            2011;8.174;;
# 5     2012;-1;2.244;2.627
# 6            2015;8.615;;

# %%
# Removing the semi-colons ';'
pd.read_csv("city_pop.csv", skiprows=5, sep=";")
# Out:
#    year  London  Paris   Rome
# 0  2001   7.322  2.148  2.547
# 1  2006   7.652    NaN  2.627
# 2  2008  -1.000  2.211    NaN
# 3  2009  -1.000  2.234  2.734
# 4  2011   8.174    NaN    NaN
# 5  2012  -1.000  2.244  2.627
# 6  2015   8.615    NaN    NaN

# %%
# Giving a Nan value to rows with -1 rainfall
pd.read_csv("city_pop.csv", skiprows=5, sep=";", na_values = "-1")
# Out:
#    year  London  Paris   Rome
# 0  2001   7.322  2.148  2.547
# 1  2006   7.652    NaN  2.627
# 2  2008     NaN  2.211    NaN
# 3  2009     NaN  2.234  2.734
# 4  2011   8.174    NaN    NaN
# 5  2012     NaN  2.244  2.627
# 6  2015   8.615    NaN    NaN

# %% [markdown]
# ## Setting up a different index

# %%
# use the year column as the index for the DataFrame
pd.read_csv("city_pop.csv", skiprows=5, sep=";", na_values = "-1", index_col = "year")
# Out:
#       London  Paris   Rome
# year
# 2001   7.322  2.148  2.547
# 2006   7.652    NaN  2.627
# 2008     NaN  2.211    NaN
# 2009     NaN  2.234  2.734
# 2011   8.174    NaN    NaN
# 2012     NaN  2.244  2.627
# 2015   8.615    NaN    NaN

# %%
myfile = "cetml1659on.txt"

# %%
df = pd.read_csv(myfile, 
                 skiprows = 6, 
                 delim_whitespace=True,
                 na_values = ["-99.99", "99.99"])

# %%
df.head()
# Out:
#       JAN  FEB  MAR  APR   MAY   JUN   JUL   AUG   SEP   OCT  NOV  DEC  YEAR
# 1659  3.0  4.0  6.0  7.0  11.0  13.0  16.0  16.0  13.0  10.0  5.0  2.0  8.87
# 1660  0.0  4.0  6.0  9.0  11.0  14.0  15.0  16.0  13.0  10.0  6.0  5.0  9.10
# 1661  5.0  5.0  6.0  8.0  11.0  14.0  15.0  15.0  13.0  11.0  8.0  6.0  9.78
# 1662  5.0  6.0  6.0  8.0  11.0  15.0  15.0  15.0  13.0  11.0  6.0  3.0  9.52
# 1663  1.0  1.0  5.0  7.0  10.0  14.0  15.0  15.0  13.0  10.0  7.0  5.0  8.63

# %%
tips = pd.read_csv("tips.csv")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
tips[['total_bill', 'tip']]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
#I f you want to select a row from a DataFrame then you can use the .loc (short for "location") attribute 
# which allows you to pass index values like:

tips.loc[3]
# Out:
# total_bill     23.68
# tip             3.31
# sex             Male
# smoker            No
# day              Sun
# time          Dinner
# size               2
# Name: 3, dtype: object

# %%
# To grab a single value from the table,
tips.loc[3, 'total_bill']
# Out:
# 23.68

# %%
# The size column in the data is the number of people in the dining party.
tips["size"]
# Out:
# 0      2
# 1      3
# 2      3
# 3      2
# 4      4
#       ..
# 239    3
# 240    2
# 241    2
# 242    2
# 243    2
# Name: size, Length: 244, dtype: int64

# %% [markdown]
# ## Descriptive Statistics

# %%
print('Sum of all total_bills:',tips['total_bill'].sum())
# Out:
# Sum of all total_bills: 4827.77

# %%
print('Average total_bill:',tips['total_bill'].mean())
# Out:
# Average total_bill: 19.785942622950824

# %%
print('Maximun tip:',tips['tip'].max())
print('Maximun total_bill:',tips['total_bill'].max())
# Out:
# Maximun tip: 10.0
# Maximun total_bill: 50.81

# %%
# In some situations, you don't just want to get the value of the maximum, but rather to find out which row it came from.
# In cases like that there is the idxmax() method which give you the index label of the row with the maximum:
print('Index Location:',tips['total_bill'].idxmax())
# Out:
# Index Location: 170

# %%
tips.loc[170]
# Out:
# total_bill     50.81
# tip             10.0
# sex             Male
# smoker           Yes
# day              Sat
# time          Dinner
# size               3
# Name: 170, dtype: object

# %%
print('Minimun total_bill:',tips['total_bill'].min())
print('Minimun tip:', tips['tip'].min())
# Out:
# Minimun total_bill: 3.07
# Minimun tip: 1.0

# %%
tips['tip']*10
# Out:
# 0      10.1
# 1      16.6
# 2      35.0
# 3      33.1
# 4      36.1
#        ...
# 239    59.2
# 240    20.0
# 241    20.0
# 242    17.5
# 243    30.0
# Name: tip, Length: 244, dtype: float64

# %% [markdown]
# ## **Combining Columns**

# %%
per_cent = (tips['tip']/tips['total_bill'])*100

# %%
per_cent
# Out:
# 0       5.944673
# 1      16.054159
# 2      16.658734
# 3      13.978041
# 4      14.680765
#          ...
# 239    20.392697
# 240     7.358352
# 241     8.822232
# 242     9.820426
# 243    15.974441
# Length: 244, dtype: float64

# %%
print('Amount spent per person:\n', tips['total_bill']+tips['tip'])
# Out:
# Amount spent per person:
#  0      18.00
# 1      12.00
# 2      24.51
# 3      26.99
# 4      28.20
#        ...
# 239    34.95
# 240    29.18
# 241    24.67
# 242    19.57
# 243    21.78
# Length: 244, dtype: float64

# %% [markdown]
# **Calculation the Average: mean()**

# %%
print('Average spent per table:', (tips['total_bill'].sum()+tips['tip'].sum())/244)
# Out:
# Average spent per table: 22.784221311475413

# %%
tm = tips['total_bill'].mean() + tips['tip'].mean()
tm
# Out:
# 22.784221311475413

# %% [markdown]
# ## Adding New Columns

# %%
tips['percent_tip'] = ((tips['tip']/tips['total_bill'])*100)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  percent_tip
# 0         16.99  1.01  Female     No   Sun  Dinner     2     5.944673
# 1         10.34  1.66    Male     No   Sun  Dinner     3    16.054159
# 2         21.01  3.50    Male     No   Sun  Dinner     3    16.658734
# 3         23.68  3.31    Male     No   Sun  Dinner     2    13.978041
# 4         24.59  3.61  Female     No   Sun  Dinner     4    14.680765
# ..          ...   ...     ...    ...   ...     ...   ...          ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3    20.392697
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2     7.358352
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2     8.822232
# 242       17.82  1.75    Male     No   Sat  Dinner     2     9.820426
# 243       18.78  3.00  Female     No  Thur  Dinner     2    15.974441
#
# [244 rows x 8 columns]

# %%
tips['bill_per_person'] = tips['total_bill'] / tips['size']
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  percent_tip  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2     5.944673
# 1         10.34  1.66    Male     No   Sun  Dinner     3    16.054159
# 2         21.01  3.50    Male     No   Sun  Dinner     3    16.658734
# 3         23.68  3.31    Male     No   Sun  Dinner     2    13.978041
# 4         24.59  3.61  Female     No   Sun  Dinner     4    14.680765
# ..          ...   ...     ...    ...   ...     ...   ...          ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3    20.392697
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2     7.358352
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2     8.822232
# 242       17.82  1.75    Male     No   Sat  Dinner     2     9.820426
# 243       18.78  3.00  Female     No  Thur  Dinner     2    15.974441
#
#      bill_per_person
# 0           8.495000
# 1           3.446667
# 2           7.003333
# 3          11.840000
# ...

# %%
# plotting the relationship between the percentage tip, and the bill per-person.
# Set the colour of the data points to be based on the day of the week.

import seaborn as sns
sns.set_theme()
sns.relplot(data=tips, x='bill_per_person', y='percent_tip', hue='day')

# %% [markdown]
# ## Filtering Data

# %% [markdown]
# In Pandas there are two steps to asking a question like this.
#
#  - create a filter which describes the question you want to ask
#  - apply that filter to the data to get just the bits you are interested in
# You create a filter by performing some operation on your DataFrame or a column within it. To ask about only those rows which refer to Saturday, you grab the day column and compare it to "Sat":

# %%
tips = pd.read_csv("tips.csv")

# %%
tips['day'] == 'Sat'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239     True
# 240     True
# 241     True
# 242     True
# 243    False
# Name: day, Length: 244, dtype: bool

# %%
# We could save this filter as a variable:
sat_filter = tips['day'] == 'Sat'

# %% [markdown]
# """ We can use this to filter the DataFrame as a whole. tips["day"] == "Sat" has returned a Series containing
# booleans. Passing it back into tips as an indexing operation will use it to filter based on the day column,
# only keeping those rows which contained True in the filter:"""

# %%
tips[sat_filter]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-b9dd323a533a> in <module>
# ----> 1 tips[sat_filter]
#
# NameError: name 'sat_filter' is not defined

# %%
# It is more common to do this in one step, rather than creating and naming a filter object. So the code becomes:
tips[tips['day'] == 'Sat']
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 19        20.65  3.35    Male     No  Sat  Dinner     3
# 20        17.92  4.08    Male     No  Sat  Dinner     2
# 21        20.29  2.75  Female     No  Sat  Dinner     2
# 22        15.77  2.23  Female     No  Sat  Dinner     2
# 23        39.42  7.58    Male     No  Sat  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3
# 239       29.03  5.92    Male     No  Sat  Dinner     3
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2
# 242       17.82  1.75    Male     No  Sat  Dinner     2
#
# [87 rows x 7 columns]

# %% [markdown]
# **Exercise 1**
#  - Select the data for only Thursdays.
#  - Calculate the mean of the tip column for Thursdays
#  - Compare this with the mean of the tip column for Saturdays

# %%
# Creating the Filter
thur_filter = tips[tips['day'] == 'Thur']

# %%
thur_filter
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 77        27.20  4.00    Male     No  Thur   Lunch     4
# 78        22.76  3.00    Male     No  Thur   Lunch     2
# 79        17.29  2.71    Male     No  Thur   Lunch     2
# 80        19.44  3.00    Male    Yes  Thur   Lunch     2
# 81        16.66  3.40    Male     No  Thur   Lunch     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 202       13.00  2.00  Female    Yes  Thur   Lunch     2
# 203       16.40  2.50  Female    Yes  Thur   Lunch     2
# 204       20.53  4.00    Male    Yes  Thur   Lunch     4
# 205       16.47  3.23  Female    Yes  Thur   Lunch     3
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [62 rows x 7 columns]

# %%
# Calculting the Mean:
thur_filter['tip'].mean()
# Out:
# 2.771451612903226

# %%
tips[tips['day'] == 'Sat']['tip'].mean()
# Out:
# 2.993103448275862

# %% [markdown]
# ### Other filters
#  - As well as filtering with the == operator (which only checks for exact matches), you can do other types of comparisons.
#  - Any of the standard Python comparisons will work (i.e. ==, !=, <, <=, >, >=).
#
# To grab only the rows where the total bill is less than $8 we can use <:

# %%
tips[tips['total_bill'] < 8]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1
# 92         5.75  1.00  Female    Yes   Fri  Dinner     2
# 111        7.25  1.00  Female     No   Sat  Dinner     1
# 149        7.51  2.00    Male     No  Thur   Lunch     2
# 172        7.25  5.15    Male    Yes   Sun  Dinner     2
# 195        7.56  1.44    Male     No  Thur   Lunch     2
# 218        7.74  1.44    Male    Yes   Sat  Dinner     2

# %%
# Filter the data to only include parties of 5 or more people.
tips[tips['size'] >= 5]

# %% [markdown]
# ### Combining filters
#  - If you want to apply multiple filters, for example to select only "Saturdays with small total bills" you cando it in one of two different ways. Either split the question into multiple steps, or ask it all at once.
#
# Let's do it multiple steps first since we already have tools we need for that:

# %%
sat_tips = tips[tips["day"] == "Sat"]  # First grab the Saturday data and save it as a variable
sat_tips[sat_tips["total_bill"] >= 35]   # Then act on the new DataFrame as use it as before
# Out:
#      total_bill    tip     sex smoker  day    time  size
# 23        39.42   7.58    Male     No  Sat  Dinner     4
# 56        38.01   3.00    Male    Yes  Sat  Dinner     4
# 59        48.27   6.73    Male     No  Sat  Dinner     4
# 102       44.30   2.50  Female    Yes  Sat  Dinner     3
# 170       50.81  10.00    Male    Yes  Sat  Dinner     3
# 207       38.73   3.00    Male    Yes  Sat  Dinner     4
# 212       48.33   9.00    Male     No  Sat  Dinner     4
# 238       35.83   4.67  Female     No  Sat  Dinner     3

# %% [markdown]
# Or, you can combine the questions together using the & operator with a syntax like:
#
# df[(filter_1) & (filter_2)]
#
# so in our case filter 1 is tips["day"] == "Sat" and filter 2 is tips["total_bill"] >= 35 so it becomes:

# %%
tips[(tips['day'] == 'Sat') & (tips['total_bill'] >= 35)]
# Out:
#      total_bill    tip     sex smoker  day    time  size
# 23        39.42   7.58    Male     No  Sat  Dinner     4
# 56        38.01   3.00    Male    Yes  Sat  Dinner     4
# 59        48.27   6.73    Male     No  Sat  Dinner     4
# 102       44.30   2.50  Female    Yes  Sat  Dinner     3
# 170       50.81  10.00    Male    Yes  Sat  Dinner     3
# 207       38.73   3.00    Male    Yes  Sat  Dinner     4
# 212       48.33   9.00    Male     No  Sat  Dinner     4
# 238       35.83   4.67  Female     No  Sat  Dinner     3

# %% [markdown]
# If you want to do an "or" operation, then instead of & you can use |.

# %%
# Filter the data to only include parties of 4 or more people which happened at lunch time.
tips[(tips['size'] >=4) & (tips['time'] == 'Lunch')]
# Out:
#      total_bill   tip     sex smoker   day   time  size
# 77        27.20  4.00    Male     No  Thur  Lunch     4
# 85        34.83  5.17  Female     No  Thur  Lunch     4
# 119       24.08  2.92  Female     No  Thur  Lunch     4
# 125       29.80  4.20  Female     No  Thur  Lunch     6
# 141       34.30  6.70    Male     No  Thur  Lunch     6
# 142       41.19  5.00    Male     No  Thur  Lunch     5
# 143       27.05  5.00  Female     No  Thur  Lunch     6
# 197       43.11  5.00  Female    Yes  Thur  Lunch     4
# 204       20.53  4.00    Male    Yes  Thur  Lunch     4
